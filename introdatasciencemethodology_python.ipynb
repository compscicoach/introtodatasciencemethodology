# %% [markdown]
# # Interactive Introduction to Data Science Methodology Notebook
# ![alt text](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png "Title")
#
# Within the umbrella of data science are different subset areas such as data analytics, machine learning, deeplearning/neural networks and AI.
#
# ![datasciencemethodologyumbrella.png](img/datascienceumbrella.png)
#
#
# **Data Analytics' subset has 4 main parts each serving a different purpose:**
#
# - Descriptive Question: What has happened? (Think visual representation of events)
# - Diagnostic Question: Why did this happen?(Think root cause)
# - Prescriptive Question: How can we fix it? (Think health industry recommending a medicine or course of treatment based on symptoms)
# - Predictive Question: What will they want next?(Think recommender systems like Amazon, Netflix)
#
# [tools&libsusedfordatascience](tools&libsusedfordatascience.txt)
#
#
# ## What is Data Science & Its Methodology?
# ![datasciencemethodologyflowchart.png](img/datasciencemethodologyflowchart.png)
#
#
#
# The first step in data science methodology is to ask a question in which data science can be used to solve it. Don't get caught up in the tools themselves or the data first.Data science methodology begins with spending the time to seek clarification, by asking clarifying questions to attain what can be referred to as a business understanding, then you determine which data will be used to answer the core question.
#
# List of Data Science Questions & Associated Algorithms:
# [QuestionsDataScienceCanAnswer_AlgorithmsAssociated](https://github.com/compscicoach/introtodatasciencemethodology/blob/master/QuestionsDataScienceCanAnswer_AlgorithmsAssociated.xlsx)
#
#
# # A Day in the Life of a Data Scientist Script
#
#
# ## __Step 1: Business Understanding (The Business Problem: What is the Question I am trying to solve in which applying data science methodology will help to answer?)
#
# I am Dan the data scientist and my boss Mr. Washington has asked me to solve the following business problem: What gender has purchased more vehicles this year? Is there a specific make/model of vehicle preferred by gender to target a campaign? Are there specific features preferred most?
#
# To Clarify I ask Mr. Washington these clarifying questions: Do you hope to increase profitability of a certain model? overall profitability? He tells me he wishes to potentially replace an underperforming model and provide recommendations to the customer based on preferences.He wants to know what is the view of his business
# ## __Step 2: Analytic Approach (Choosing the right Machine Learning Algorithm Used to Solve)
#
# Sample Questions & Regression(Statistical Modeling) or Classification approach to obtaining the answer)
#
# - Regression(Relationship) Sample Question: Is there a relationship between time spent under sun and plant height?
#       Y = f(x)
#    -  Y is plant height
#    -  f is any model representative of the relationship
#    <br>
#    -  x is time plant spent in sun
#    <br>
# - Classification Yes/No Sample Question: Which animal is in a given image?
#       Y = f(x)
#   -  Y is {dog, cat, horse, other}
#   -  f represents any model that captures the relationship
#       <br>
#  -  x would be images encoded into tabular form
#     <br>
# - Regression(Prediction) Sample Question: What factors best predict electricity demand?
#        Y =f(x)
#
#    -  Y = quantity of electricity demanded
#        <br>
#    - f any model capturing relationship between your data and electricity demanded
#        <br>
#    - x probably has the features price, temperature, season, region,other features
#      <br>
# ## __Step 3: Data Requirements (Requirements of the Business)
#
# ### Sample Requirements: Goal is to predict x y z outcome/understand combination of events causing prediction of those outcomes in an easy to understand format to apply predictions
#
# - What does the picture of my business look like?
# - Which car models are selling the least?
# - What factors can impact what recommendations I give to my customers?
#
# ## __Step 4: Data Science Tools chosen based on Step 1,2,3 above__
#
#    - Factors to consider:
#       <br>
#       - Type of data I am analyzing: Unstructured, Structured, Semi-structured
#        <br>
#       - Language best suited for data: R, SQL, Python
#       <br>
#       - Depending on the type of question you seek to answer will dictate method used e.g. data aggregation (preprocessing/prep of raw) vs. data wrangling(prep during analysis/model building
#       <br>
#       - Visualizations you'd like
#
# ## __Step 5: Locate the data you will use for analysis into Python(Data Collection)
#
#   Note the following:
# - For the purpose of this exercise we've already generated fake data(Mockaroo) stored in this Jupyter notebook.
# - __We will now illustrate how to locate & read a JSON data file(semi-structured) you want to use for analysis using the Python code below__
# - __For the purpose of this notebook illustration I only use data from one source but normally data aggregation is a step in the process, which takes multiple data sources consolidates into one location for analysis__
# - __Tip: To execute the Python code in the grey code cell below, click on it and press Shift + Enter & then clear the cell's output (if you wish)__

# %%
#testing out opening and reading JSON data file
with open("/users/brandyguillory/Jupyter Files/pricedata.json","r") as File1:
    Stuff_In_File = File1.read()
print(Stuff_In_File)
# Out:
# [{"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Samoan","job title":"Marketing Assistant","car model year":1984,"car make":"Mazda","car model":"RX-7","price":"4,323 Yuan Renminbi"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Creek","job title":"Chief Design Engineer","car model year":1997,"car make":"Buick","car model":"Park Avenue","price":"95,173 Euro"},
# {"currency":"Shilling","currency code":"UGX","gender":"Female","race":"Costa Rican","job title":"Senior Cost Accountant","car model year":1995,"car make":"Mitsubishi","car model":"Pajero","price":"458,483 Shilling"},
# {"currency":"Dollar","currency code":"CAD","gender":"Female","race":"Seminole","job title":"Assistant Manager","car model year":2000,"car make":"Chevrolet","car model":"Tracker","price":"08,262 Dollar"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Laotian","job title":"Senior Financial Analyst","car model year":1998,"car make":"Ford","car model":"Taurus","price":"6,854 Euro"},
# {"currency":"Naira","currency code":"NGN","gender":"Female","race":"Hmong","job title":"Registered Nurse","car model year":1996,"car make":"Dodge","car model":"Stratus","price":"20,459 Naira"},
# {"currency":"Real","currency code":"BRL","gender":"Male","race":"Lumbee","job title":"Product Engineer","car model year":2001,"car make":"Acura","car model":"RL","price":"6,635 Real"},
# {"currency":"Real","currency code":"BRL","gender":"Female","race":"Melanesian","job title":"Programmer Analyst III","car model year":2012,"car make":"Volkswagen","car model":"Passat","price":"59,099 Real"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Samoan","job title":"Financial Advisor","car model year":2006,"car make":"Lexus","car model":"ES","price":"4,144 Euro"},
# {"currency":"Ruble","currency code":"RUB","gender":"Male","race":"Mexican","job title":"Accountant III","car model year":2006,"car make":"Chrysler","car model":"Town & Country","price":"440,768 Ruble"},
# {"currency":"Bolivar","currency code":"VEF","gender":"Male","race":"Central American","job title":"Research Assistant IV","car model year":1989,"car make":"Saab","car model":"9000","price":"00,968 Bolivar"},
# {"currency":"Zloty","currency code":"PLN","gender":"Male","race":"Cuban","job title":"Legal Assistant","car model year":2000,"car make":"Chevrolet","car model":"Camaro","price":"6,076 Zloty"},
# {"currency":"Tugrik","currency code":"MNT","gender":"Female","race":"Black or African American","job title":"Database Administrator III","car model year":1992,"car make":"Ford","car model":"F-Series","price":"0,370 Tugrik"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Sri Lankan","job title":"Senior Developer","car model year":2007,"car make":"Mercedes-Benz","car model":"CL-Class","price":"5,593 Rupiah"},
# {"currency":"Peso","currency code":"ARS","gender":"Female","race":"Thai","job title":"Human Resources Manager","car model year":2011,"car make":"Honda","car model":"CR-Z","price":"920,722 Peso"},
# {"currency":"Real","currency code":"BRL","gender":"Male","race":"Comanche","job title":"Human Resources Assistant III","car model year":2002,"car make":"Chevrolet","car model":"Avalanche","price":"78,780 Real"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Cheyenne","job title":"Professor","car model year":1995,"car make":"Chevrolet","car model":"Astro","price":"0,497 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Lumbee","job title":"Geological Engineer","car model year":2007,"car make":"Suzuki","car model":"Daewoo Lacetti","price":"4,981 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Lumbee","job title":"Chemical Engineer","car model year":1993,"car make":"Lamborghini","car model":"Diablo","price":"681,627 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Polynesian","job title":"Clinical Specialist","car model year":2006,"car make":"Acura","car model":"RL","price":"7,905 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Thai","job title":"Product Engineer","car model year":2008,"car make":"Mazda","car model":"B-Series","price":"241,265 Rupiah"},
# {"currency":"Ruble","currency code":"RUB","gender":"Male","race":"Bolivian","job title":"Financial Advisor","car model year":1995,"car make":"Mercury","car model":"Villager","price":"2,660 Ruble"},
# {"currency":"Dinar","currency code":"TND","gender":"Male","race":"Panamanian","job title":"Product Engineer","car model year":1997,"car make":"Saab","car model":"9000","price":"3,227 Dinar"},
# {"currency":"Dollar","currency code":"CAD","gender":"Female","race":"Navajo","job title":"Analyst Programmer","car model year":2012,"car make":"Maybach","car model":"57","price":"16,491 Dollar"},
# {"currency":"Kyat","currency code":"MMK","gender":"Male","race":"Salvadoran","job title":"Senior Quality Engineer","car model year":2002,"car make":"Chevrolet","car model":"Express 1500","price":"2,094 Kyat"},
# {"currency":"Afghani","currency code":"AFN","gender":"Female","race":"South American","job title":"Financial Analyst","car model year":1996,"car make":"Lexus","car model":"LS","price":"85,769 Afghani"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Asian","job title":"Occupational Therapist","car model year":2004,"car make":"Lamborghini","car model":"Gallardo","price":"909,737 Rupiah"},
# {"currency":"Peso","currency code":"COP","gender":"Male","race":"Panamanian","job title":"Accountant II","car model year":2012,"car make":"Mercedes-Benz","car model":"SL-Class","price":"15,448 Peso"},
# {"currency":"Rupee","currency code":"PKR","gender":"Male","race":"Comanche","job title":"Human Resources Manager","car model year":2000,"car make":"Kia","car model":"Sportage","price":"749,567 Rupee"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Filipino","job title":"Nurse Practicioner","car model year":1989,"car make":"Toyota","car model":"Truck Xtracab SR5","price":"866,139 Yuan Renminbi"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Pueblo","job title":"Teacher","car model year":2011,"car make":"Chevrolet","car model":"Express 1500","price":"35,151 Euro"},
# {"currency":"Franc","currency code":"XOF","gender":"Male","race":"Chickasaw","job title":"Media Manager IV","car model year":2011,"car make":"Mazda","car model":"CX-9","price":"77,093 Franc"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Delaware","job title":"Engineer I","car model year":1996,"car make":"Ford","car model":"Econoline E250","price":"45,560 Euro"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Dominican (Dominican Republic)","job title":"Mechanical Systems Engineer","car model year":2011,"car make":"Chevrolet","car model":"Avalanche","price":"841,868 Yuan Renminbi"},
# {"currency":"Koruna","currency code":"CZK","gender":"Male","race":"Tongan","job title":"Account Representative III","car model year":2002,"car make":"Pontiac","car model":"Bonneville","price":"34,010 Koruna"},
# {"currency":"Dinar","currency code":"JOD","gender":"Male","race":"Hmong","job title":"Professor","car model year":2011,"car make":"Infiniti","car model":"M","price":"60,299 Dinar"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Taiwanese","job title":"Financial Analyst","car model year":2011,"car make":"Acura","car model":"RDX","price":"00,015 Euro"},
# {"currency":"Dong","currency code":"VND","gender":"Male","race":"Bangladeshi","job title":"Recruiting Manager","car model year":2008,"car make":"Mazda","car model":"Mazdaspeed 3","price":"295,107 Dong"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Alaskan Athabascan","job title":"Registered Nurse","car model year":1968,"car make":"Pontiac","car model":"Bonneville","price":"25,206 Peso"},
# {"currency":"Sol","currency code":"PEN","gender":"Female","race":"Bangladeshi","job title":"Automation Specialist I","car model year":1995,"car make":"Chevrolet","car model":"Monte Carlo","price":"59,577 Sol"},
# {"currency":"Peso","currency code":"CLP","gender":"Female","race":"Pueblo","job title":"Geologist I","car model year":2012,"car make":"Maserati","car model":"Quattroporte","price":"870,504 Peso"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Ute","job title":"Design Engineer","car model year":1993,"car make":"Dodge","car model":"D150","price":"5,947 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Bangladeshi","job title":"Graphic Designer","car model year":1987,"car make":"Maserati","car model":"Biturbo","price":"7,012 Rupiah"},
# {"currency":"Dinar","currency code":"JOD","gender":"Male","race":"Venezuelan","job title":"Nuclear Power Engineer","car model year":1993,"car make":"Mazda","car model":"323","price":"712,773 Dinar"},
# {"currency":"Rupee","currency code":"PKR","gender":"Male","race":"Central American","job title":"Database Administrator IV","car model year":1995,"car make":"Infiniti","car model":"G","price":"0,446 Rupee"},
# {"currency":"Yen","currency code":"JPY","gender":"Female","race":"Colville","job title":"Technical Writer","car model year":1994,"car make":"Honda","car model":"del Sol","price":"88,624 Yen"},
# {"currency":"Dollar","currency code":"USD","gender":"Female","race":"Aleut","job title":"Legal Assistant","car model year":1993,"car make":"Chrysler","car model":"Fifth Ave","price":"99,003 Dollar"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Menominee","job title":"Budget/Accounting Analyst III","car model year":2008,"car make":"Land Rover","car model":"Freelander","price":"2,404 Yuan Renminbi"},
# {"currency":"Dollar","currency code":"CAD","gender":"Male","race":"Sri Lankan","job title":"Senior Quality Engineer","car model year":2007,"car make":"Hyundai","car model":"Azera","price":"533,463 Dollar"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Spaniard","job title":"Statistician I","car model year":2012,"car make":"BMW","car model":"X5 M","price":"6,036 Yuan Renminbi"},
# {"currency":"Franc","currency code":"XOF","gender":"Female","race":"Iroquois","job title":"Media Manager III","car model year":2010,"car make":"Volvo","car model":"C30","price":"04,321 Franc"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Nicaraguan","job title":"Statistician IV","car model year":2007,"car make":"Buick","car model":"Terraza","price":"753,168 Euro"},
# {"currency":"Shekel","currency code":"ILS","gender":"Female","race":"South American","job title":"Social Worker","car model year":1996,"car make":"Mazda","car model":"626","price":"12,424 Shekel"},
# {"currency":"Peso","currency code":"PHP","gender":"Male","race":"Tongan","job title":"Community Outreach Specialist","car model year":2001,"car make":"Mazda","car model":"MX-5","price":"20,192 Peso"},
# {"currency":"Shilling","currency code":"TZS","gender":"Male","race":"Costa Rican","job title":"Financial Advisor","car model year":2001,"car make":"Audi","car model":"S4","price":"74,308 Shilling"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Black or African American","job title":"Software Engineer III","car model year":2012,"car make":"Dodge","car model":"Journey","price":"8,828 Rupiah"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Asian Indian","job title":"Research Nurse","car model year":1994,"car make":"Chrysler","car model":"Concorde","price":"456,553 Yuan Renminbi"},
# {"currency":"Dollar","currency code":"USD","gender":"Male","race":"Cuban","job title":"Automation Specialist I","car model year":2008,"car make":"Mitsubishi","car model":"Galant","price":"92,595 Dollar"},
# {"currency":"Baht","currency code":"THB","gender":"Female","race":"Fijian","job title":"Statistician IV","car model year":2008,"car make":"Acura","car model":"TL","price":"883,411 Baht"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Tlingit-Haida","job title":"Executive Secretary","car model year":1991,"car make":"Buick","car model":"Regal","price":"44,943 Euro"},
# {"currency":"Franc","currency code":"CDF","gender":"Male","race":"American Indian and Alaska Native (AIAN)","job title":"Administrative Officer","car model year":2010,"car make":"Lincoln","car model":"MKS","price":"3,110 Franc"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Japanese","job title":"Librarian","car model year":1998,"car make":"Audi","car model":"A4","price":"58,871 Yuan Renminbi"},
# {"currency":"Rial","currency code":"IRR","gender":"Female","race":"Filipino","job title":"Analog Circuit Design manager","car model year":2012,"car make":"Honda","car model":"Ridgeline","price":"9,419 Rial"},
# {"currency":"Shekel","currency code":"ILS","gender":"Male","race":"Apache","job title":"Financial Analyst","car model year":2010,"car make":"Bentley","car model":"Azure","price":"78,160 Shekel"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Chippewa","job title":"Cost Accountant","car model year":1994,"car make":"Toyota","car model":"Supra","price":"931,109 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Puget Sound Salish","job title":"Administrative Officer","car model year":2008,"car make":"Mercedes-Benz","car model":"SLR McLaren","price":"397,828 Rupiah"},
# {"currency":"Ruble","currency code":"RUB","gender":"Male","race":"Taiwanese","job title":"Geologist I","car model year":1995,"car make":"Suzuki","car model":"Samurai","price":"1,084 Ruble"},
# {"currency":"Marka","currency code":"BAM","gender":"Female","race":"Peruvian","job title":"Financial Advisor","car model year":1987,"car make":"Mitsubishi","car model":"Starion","price":"3,444 Marka"},
# {"currency":"Real","currency code":"BRL","gender":"Female","race":"Shoshone","job title":"Senior Developer","car model year":2010,"car make":"Infiniti","car model":"QX56","price":"48,570 Real"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Paiute","job title":"Professor","car model year":2005,"car make":"BMW","car model":"X5","price":"0,602 Yuan Renminbi"},
# {"currency":"Zloty","currency code":"PLN","gender":"Female","race":"Comanche","job title":"Graphic Designer","car model year":1995,"car make":"Chrysler","car model":"Sebring","price":"60,854 Zloty"},
# {"currency":"Real","currency code":"BRL","gender":"Female","race":"Ottawa","job title":"Nurse","car model year":1993,"car make":"Mitsubishi","car model":"Expo","price":"3,625 Real"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Spaniard","job title":"Nurse Practicioner","car model year":1993,"car make":"Hyundai","car model":"Excel","price":"0,463 Euro"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Osage","job title":"Structural Analysis Engineer","car model year":2012,"car make":"Hyundai","car model":"Sonata","price":"457,212 Rupiah"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Blackfeet","job title":"Account Executive","car model year":2009,"car make":"Acura","car model":"RDX","price":"2,794 Euro"},
# {"currency":"Peso","currency code":"MXN","gender":"Male","race":"Chamorro","job title":"Software Test Engineer II","car model year":2010,"car make":"Kia","car model":"Sportage","price":"56,860 Peso"},
# {"currency":"Peso","currency code":"ARS","gender":"Female","race":"Aleut","job title":"Geological Engineer","car model year":1992,"car make":"Chevrolet","car model":"Corsica","price":"2,270 Peso"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Salvadoran","job title":"Environmental Tech","car model year":1985,"car make":"Porsche","car model":"911","price":"951,526 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Chilean","job title":"Web Designer III","car model year":2005,"car make":"Nissan","car model":"Maxima","price":"080,285 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"American Indian and Alaska Native (AIAN)","job title":"Safety Technician II","car model year":2003,"car make":"Nissan","car model":"Sentra","price":"7,507 Yuan Renminbi"},
# {"currency":"Dirham","currency code":"MAD","gender":"Female","race":"Seminole","job title":"Nurse Practicioner","car model year":2007,"car make":"BMW","car model":"5 Series","price":"5,714 Dirham"},
# {"currency":"Dollar","currency code":"USD","gender":"Male","race":"Chamorro","job title":"Project Manager","car model year":2006,"car make":"Toyota","car model":"4Runner","price":"9,058 Dollar"},
# {"currency":"Zloty","currency code":"PLN","gender":"Male","race":"Laotian","job title":"Junior Executive","car model year":2006,"car make":"Mazda","car model":"MX-5","price":"96,587 Zloty"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Kiowa","job title":"Marketing Assistant","car model year":1967,"car make":"Mercury","car model":"Cougar","price":"57,406 Yuan Renminbi"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Cheyenne","job title":"Payment Adjustment Coordinator","car model year":2010,"car make":"Volvo","car model":"XC90","price":"6,358 Peso"},
# {"currency":"Sol","currency code":"PEN","gender":"Male","race":"Korean","job title":"Biostatistician II","car model year":2008,"car make":"Audi","car model":"S5","price":"91,733 Sol"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Polynesian","job title":"VP Sales","car model year":2006,"car make":"Lexus","car model":"SC","price":"0,754 Yuan Renminbi"},
# {"currency":"Dong","currency code":"VND","gender":"Female","race":"Bolivian","job title":"Compensation Analyst","car model year":2010,"car make":"Mazda","car model":"RX-8","price":"4,770 Dong"},
# {"currency":"Peso","currency code":"PHP","gender":"Male","race":"Eskimo","job title":"Account Representative II","car model year":1997,"car make":"Dodge","car model":"Caravan","price":"7,281 Peso"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Potawatomi","job title":"Director of Sales","car model year":2003,"car make":"Ford","car model":"ZX2","price":"417,234 Euro"},
# {"currency":"Peso","currency code":"MXN","gender":"Male","race":"Cheyenne","job title":"Web Designer I","car model year":2007,"car make":"Ford","car model":"F250","price":"2,161 Peso"},
# {"currency":"Ruble","currency code":"RUB","gender":"Female","race":"Chinese","job title":"Analyst Programmer","car model year":1984,"car make":"Maserati","car model":"Quattroporte","price":"335,670 Ruble"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Tohono O'Odham","job title":"Office Assistant III","car model year":2011,"car make":"Ford","car model":"Flex","price":"11,761 Rupiah"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Samoan","job title":"Senior Editor","car model year":1989,"car make":"Maserati","car model":"430","price":"787,465 Euro"},
# {"currency":"Yen","currency code":"JPY","gender":"Female","race":"Venezuelan","job title":"Assistant Media Planner","car model year":2011,"car make":"Mercedes-Benz","car model":"GL-Class","price":"41,474 Yen"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Venezuelan","job title":"Recruiting Manager","car model year":2009,"car make":"Volkswagen","car model":"GTI","price":"67,497 Yuan Renminbi"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Tohono O'Odham","job title":"Staff Scientist","car model year":2010,"car make":"Bentley","car model":"Azure T","price":"339,144 Euro"},
# {"currency":"Baht","currency code":"THB","gender":"Male","race":"Pueblo","job title":"Nuclear Power Engineer","car model year":2001,"car make":"Oldsmobile","car model":"Aurora","price":"513,616 Baht"},
# {"currency":"Denar","currency code":"MKD","gender":"Male","race":"Kiowa","job title":"Database Administrator I","car model year":1985,"car make":"Subaru","car model":"Brat","price":"947,368 Denar"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Cheyenne","job title":"Product Engineer","car model year":1998,"car make":"Dodge","car model":"Dakota Club","price":"4,510 Yuan Renminbi"},
# {"currency":"Dollar","currency code":"USD","gender":"Female","race":"Yakama","job title":"Tax Accountant","car model year":2007,"car make":"Suzuki","car model":"Forenza","price":"87,602 Dollar"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Pueblo","job title":"Social Worker","car model year":1997,"car make":"Chevrolet","car model":"Suburban 2500","price":"08,926 Peso"},
# {"currency":"Shekel","currency code":"ILS","gender":"Female","race":"Lumbee","job title":"Desktop Support Technician","car model year":2010,"car make":"Kia","car model":"Sportage","price":"07,019 Shekel"},
# {"currency":"Ruble","currency code":"RUB","gender":"Male","race":"Potawatomi","job title":"Recruiting Manager","car model year":2010,"car make":"Chevrolet","car model":"Express","price":"135,068 Ruble"},
# {"currency":"Colon","currency code":"CRC","gender":"Female","race":"Japanese","job title":"Systems Administrator IV","car model year":2000,"car make":"Chrysler","car model":"Cirrus","price":"048,966 Colon"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Paraguayan","job title":"Actuary","car model year":1994,"car make":"Toyota","car model":"Camry","price":"9,151 Rupiah"},
# {"currency":"Bolivar","currency code":"VEF","gender":"Male","race":"American Indian and Alaska Native (AIAN)","job title":"Professor","car model year":1984,"car make":"Mercury","car model":"Grand Marquis","price":"663,387 Bolivar"},
# {"currency":"Dollar","currency code":"USD","gender":"Female","race":"Samoan","job title":"Office Assistant I","car model year":2001,"car make":"GMC","car model":"Savana 2500","price":"11,705 Dollar"},
# {"currency":"Kwacha","currency code":"MWK","gender":"Female","race":"South American","job title":"Engineer IV","car model year":1997,"car make":"Toyota","car model":"Paseo","price":"065,243 Kwacha"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"South American","job title":"Structural Engineer","car model year":1989,"car make":"Buick","car model":"LeSabre","price":"23,636 Peso"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Alaskan Athabascan","job title":"Analyst Programmer","car model year":2000,"car make":"Buick","car model":"LeSabre","price":"37,471 Euro"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Dominican (Dominican Republic)","job title":"Analog Circuit Design manager","car model year":2007,"car make":"Saturn","car model":"Outlook","price":"0,055 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Pueblo","job title":"Health Coach II","car model year":1996,"car make":"Nissan","car model":"Quest","price":"415,295 Yuan Renminbi"},
# {"currency":"Real","currency code":"BRL","gender":"Male","race":"Navajo","job title":"GIS Technical Architect","car model year":2000,"car make":"Acura","car model":"NSX","price":"94,594 Real"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Alaskan Athabascan","job title":"Sales Representative","car model year":2004,"car make":"Buick","car model":"Rendezvous","price":"984,381 Rupiah"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Menominee","job title":"Structural Analysis Engineer","car model year":1992,"car make":"GMC","car model":"Rally Wagon 2500","price":"10,761 Euro"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Shoshone","job title":"Paralegal","car model year":1994,"car make":"Jaguar","car model":"XJ Series","price":"373,240 Euro"},
# {"currency":"Sol","currency code":"PEN","gender":"Female","race":"Iroquois","job title":"Design Engineer","car model year":2005,"car make":"Mazda","car model":"Mazda6","price":"6,700 Sol"},
# {"currency":"Hryvnia","currency code":"UAH","gender":"Female","race":"Creek","job title":"Junior Executive","car model year":2007,"car make":"BMW","car model":"Z4 M","price":"44,503 Hryvnia"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Crow","job title":"Senior Sales Associate","car model year":1969,"car make":"Mercury","car model":"Cougar","price":"0,279 Peso"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Black or African American","job title":"Director of Sales","car model year":2009,"car make":"Saturn","car model":"Aura","price":"0,625 Yuan Renminbi"},
# {"currency":"Peso","currency code":"PHP","gender":"Male","race":"Tohono O'Odham","job title":"Database Administrator II","car model year":2005,"car make":"Ford","car model":"E350","price":"7,617 Peso"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Houma","job title":"Desktop Support Technician","car model year":2002,"car make":"BMW","car model":"5 Series","price":"3,291 Yuan Renminbi"},
# {"currency":"Hryvnia","currency code":"UAH","gender":"Female","race":"American Indian and Alaska Native (AIAN)","job title":"Research Nurse","car model year":1993,"car make":"Mercedes-Benz","car model":"300SL","price":"4,683 Hryvnia"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Spaniard","job title":"VP Quality Control","car model year":1994,"car make":"Isuzu","car model":"Rodeo","price":"0,414 Yuan Renminbi"},
# {"currency":"Tugrik","currency code":"MNT","gender":"Female","race":"Cherokee","job title":"VP Product Management","car model year":2012,"car make":"Nissan","car model":"Rogue","price":"258,862 Tugrik"},
# {"currency":"Ruble","currency code":"RUB","gender":"Female","race":"Apache","job title":"Graphic Designer","car model year":1997,"car make":"Geo","car model":"Tracker","price":"8,319 Ruble"},
# {"currency":"Baht","currency code":"THB","gender":"Male","race":"Sri Lankan","job title":"Internal Auditor","car model year":1997,"car make":"Dodge","car model":"Dakota","price":"6,001 Baht"},
# {"currency":"Dinar","currency code":"TND","gender":"Female","race":"Central American","job title":"Product Engineer","car model year":2013,"car make":"Chevrolet","car model":"Tahoe","price":"38,258 Dinar"},
# {"currency":"Sol","currency code":"PEN","gender":"Female","race":"Fijian","job title":"Administrative Assistant IV","car model year":2005,"car make":"Lotus","car model":"Elise","price":"682,486 Sol"},
# {"currency":"Ruble","currency code":"RUB","gender":"Male","race":"Comanche","job title":"Senior Cost Accountant","car model year":2001,"car make":"Ford","car model":"F150","price":"869,265 Ruble"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Alaska Native","job title":"Recruiter","car model year":2006,"car make":"Kia","car model":"Sportage","price":"35,400 Yuan Renminbi"},
# {"currency":"Pound","currency code":"GBP","gender":"Female","race":"Colombian","job title":"Operator","car model year":2004,"car make":"Spyker","car model":"C8 Spyder Wide Body","price":"33,278 Pound"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Honduran","job title":"Actuary","car model year":1996,"car make":"Ford","car model":"E-Series","price":"68,852 Yuan Renminbi"},
# {"currency":"Manat","currency code":"AZN","gender":"Female","race":"Panamanian","job title":"Information Systems Manager","car model year":1999,"car make":"GMC","car model":"Suburban 1500","price":"59,948 Manat"},
# {"currency":"Marka","currency code":"BAM","gender":"Male","race":"Costa Rican","job title":"Research Associate","car model year":2008,"car make":"Nissan","car model":"Pathfinder","price":"8,119 Marka"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Colombian","job title":"Director of Sales","car model year":1989,"car make":"Subaru","car model":"Justy","price":"83,617 Rupiah"},
# {"currency":"Ruble","currency code":"RUB","gender":"Male","race":"Guamanian","job title":"Research Assistant IV","car model year":1988,"car make":"Ford","car model":"Escort","price":"9,729 Ruble"},
# {"currency":"Peso","currency code":"ARS","gender":"Female","race":"Iroquois","job title":"Electrical Engineer","car model year":1997,"car make":"Porsche","car model":"911","price":"32,058 Peso"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Potawatomi","job title":"Editor","car model year":2010,"car make":"Lexus","car model":"IS F","price":"18,286 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Sri Lankan","job title":"Sales Associate","car model year":2006,"car make":"Morgan","car model":"Aero 8","price":"155,250 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Fijian","job title":"Sales Associate","car model year":1992,"car make":"Isuzu","car model":"Space","price":"9,925 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Pueblo","job title":"Environmental Tech","car model year":1997,"car make":"Kia","car model":"Sportage","price":"29,492 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Salvadoran","job title":"Speech Pathologist","car model year":2005,"car make":"Mazda","car model":"Mazda6","price":"578,253 Rupiah"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Nicaraguan","job title":"Computer Systems Analyst I","car model year":2006,"car make":"Honda","car model":"Civic","price":"55,595 Yuan Renminbi"},
# {"currency":"Rial","currency code":"YER","gender":"Male","race":"Melanesian","job title":"Electrical Engineer","car model year":1990,"car make":"Mercury","car model":"Cougar","price":"284,369 Rial"},
# {"currency":"Rupee","currency code":"LKR","gender":"Female","race":"Central American","job title":"Health Coach I","car model year":2008,"car make":"Kia","car model":"Carens","price":"63,424 Rupee"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Lumbee","job title":"Account Executive","car model year":2010,"car make":"Kia","car model":"Forte","price":"7,885 Rupiah"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Colville","job title":"Marketing Manager","car model year":2007,"car make":"Aston Martin","car model":"DB9","price":"87,022 Peso"},
# {"currency":"Zloty","currency code":"PLN","gender":"Female","race":"Alaska Native","job title":"Tax Accountant","car model year":2011,"car make":"BMW","car model":"X3","price":"83,669 Zloty"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Apache","job title":"Systems Administrator I","car model year":1992,"car make":"Ford","car model":"F250","price":"738,336 Yuan Renminbi"},
# {"currency":"Dollar","currency code":"CAD","gender":"Female","race":"American Indian and Alaska Native (AIAN)","job title":"Financial Analyst","car model year":2005,"car make":"Scion","car model":"tC","price":"58,349 Dollar"},
# {"currency":"Dollar","currency code":"XCD","gender":"Female","race":"Honduran","job title":"Budget/Accounting Analyst II","car model year":1961,"car make":"Studebaker","car model":"Avanti","price":"026,054 Dollar"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Fijian","job title":"Recruiter","car model year":2009,"car make":"Aston Martin","car model":"DBS","price":"910,264 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Native Hawaiian and Other Pacific Islander (NHPI)","job title":"VP Product Management","car model year":2007,"car make":"Dodge","car model":"Ram","price":"664,413 Rupiah"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Colville","job title":"Actuary","car model year":1997,"car make":"Chevrolet","car model":"2500","price":"9,591 Yuan Renminbi"},
# {"currency":"Manat","currency code":"AZN","gender":"Male","race":"Bangladeshi","job title":"Research Assistant IV","car model year":1995,"car make":"Audi","car model":"riolet","price":"56,079 Manat"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"White","job title":"Analyst Programmer","car model year":1986,"car make":"Pontiac","car model":"Safari","price":"048,884 Yuan Renminbi"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Chickasaw","job title":"Junior Executive","car model year":1992,"car make":"Eagle","car model":"Premier","price":"90,382 Euro"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Cree","job title":"Account Executive","car model year":1995,"car make":"Lexus","car model":"ES","price":"58,328 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Guatemalan","job title":"Assistant Professor","car model year":1993,"car make":"Pontiac","car model":"LeMans","price":"8,519 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Osage","job title":"Research Assistant I","car model year":1992,"car make":"Toyota","car model":"Corolla","price":"513,746 Yuan Renminbi"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Yuman","job title":"Statistician IV","car model year":1999,"car make":"Mercury","car model":"Mountaineer","price":"0,239 Euro"},
# {"currency":"Dong","currency code":"VND","gender":"Male","race":"Alaska Native","job title":"Software Engineer II","car model year":2003,"car make":"Honda","car model":"S2000","price":"56,687 Dong"},
# {"currency":"Krona","currency code":"SEK","gender":"Male","race":"Malaysian","job title":"Recruiting Manager","car model year":1985,"car make":"Subaru","car model":"Brat","price":"9,182 Krona"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Tongan","job title":"Automation Specialist I","car model year":1999,"car make":"Isuzu","car model":"Hombre Space","price":"1,035 Rupiah"},
# {"currency":"Peso","currency code":"CUP","gender":"Male","race":"Chippewa","job title":"Social Worker","car model year":2005,"car make":"GMC","car model":"Safari","price":"981,061 Peso"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"American Indian","job title":"Programmer IV","car model year":1989,"car make":"Pontiac","car model":"Gemini","price":"487,668 Rupiah"},
# {"currency":"Zloty","currency code":"PLN","gender":"Female","race":"Blackfeet","job title":"Business Systems Development Analyst","car model year":1968,"car make":"Pontiac","car model":"Grand Prix","price":"3,698 Zloty"},
# {"currency":"Afghani","currency code":"AFN","gender":"Female","race":"Colombian","job title":"Senior Cost Accountant","car model year":2005,"car make":"Nissan","car model":"Murano","price":"8,087 Afghani"},
# {"currency":"Real","currency code":"BRL","gender":"Male","race":"Laotian","job title":"Quality Engineer","car model year":1991,"car make":"Lincoln","car model":"Town Car","price":"346,438 Real"},
# {"currency":"Peso","currency code":"ARS","gender":"Female","race":"Guatemalan","job title":"Software Test Engineer III","car model year":1992,"car make":"Isuzu","car model":"Space","price":"6,315 Peso"},
# {"currency":"Peso","currency code":"COP","gender":"Female","race":"Tohono O'Odham","job title":"Analog Circuit Design manager","car model year":1992,"car make":"Chevrolet","car model":"Camaro","price":"163,741 Peso"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Delaware","job title":"Executive Secretary","car model year":1994,"car make":"Buick","car model":"Skylark","price":"214,567 Euro"},
# {"currency":"Ruble","currency code":"RUB","gender":"Female","race":"Ute","job title":"Dental Hygienist","car model year":1997,"car make":"Audi","car model":"A6","price":"07,375 Ruble"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Crow","job title":"Graphic Designer","car model year":1985,"car make":"Mitsubishi","car model":"Pajero","price":"18,540 Rupiah"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Latin American Indian","job title":"Assistant Manager","car model year":1993,"car make":"Chrysler","car model":"New Yorker","price":"925,124 Rupiah"},
# {"currency":"Real","currency code":"BRL","gender":"Male","race":"Delaware","job title":"Chemical Engineer","car model year":1993,"car make":"Eagle","car model":"Vision","price":"0,538 Real"},
# {"currency":"Taka","currency code":"BDT","gender":"Female","race":"Costa Rican","job title":"Account Representative III","car model year":2003,"car make":"GMC","car model":"Envoy","price":"82,050 Taka"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Yuman","job title":"Software Engineer II","car model year":2007,"car make":"Mercedes-Benz","car model":"C-Class","price":"09,932 Rupiah"},
# {"currency":"Hryvnia","currency code":"UAH","gender":"Male","race":"Spaniard","job title":"Legal Assistant","car model year":2007,"car make":"Toyota","car model":"Land Cruiser","price":"278,453 Hryvnia"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Costa Rican","job title":"Programmer I","car model year":2002,"car make":"Volkswagen","car model":"Cabriolet","price":"5,509 Euro"},
# {"currency":"Dollar","currency code":"USD","gender":"Male","race":"Chamorro","job title":"Financial Analyst","car model year":1990,"car make":"Mazda","car model":"Familia","price":"75,034 Dollar"},
# {"currency":"Dollar","currency code":"TWD","gender":"Male","race":"Comanche","job title":"Analog Circuit Design manager","car model year":1993,"car make":"Toyota","car model":"Tercel","price":"67,844 Dollar"},
# {"currency":"Dollar","currency code":"CAD","gender":"Female","race":"Micronesian","job title":"Programmer III","car model year":2011,"car make":"Ford","car model":"Flex","price":"541,271 Dollar"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Guamanian","job title":"Financial Analyst","car model year":2003,"car make":"Chevrolet","car model":"Astro","price":"86,072 Euro"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Tohono O'Odham","job title":"Director of Sales","car model year":2006,"car make":"Chevrolet","car model":"Cobalt","price":"7,195 Rupiah"},
# {"currency":"Hryvnia","currency code":"UAH","gender":"Male","race":"Apache","job title":"Office Assistant III","car model year":2000,"car make":"Chevrolet","car model":"Venture","price":"999,031 Hryvnia"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Guatemalan","job title":"Senior Sales Associate","car model year":2006,"car make":"Chevrolet","car model":"Corvette","price":"1,618 Peso"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"White","job title":"Senior Developer","car model year":2000,"car make":"Ford","car model":"Contour","price":"99,013 Euro"},
# {"currency":"Baht","currency code":"THB","gender":"Male","race":"Osage","job title":"Analog Circuit Design manager","car model year":2006,"car make":"Acura","car model":"RL","price":"626,192 Baht"},
# {"currency":"Ruble","currency code":"RUB","gender":"Male","race":"Houma","job title":"Physical Therapy Assistant","car model year":1995,"car make":"Oldsmobile","car model":"98","price":"0,628 Ruble"},
# {"currency":"Dollar","currency code":"USD","gender":"Female","race":"Navajo","job title":"Social Worker","car model year":1984,"car make":"Mercury","car model":"Capri","price":"93,301 Dollar"},
# {"currency":"Hryvnia","currency code":"UAH","gender":"Female","race":"Honduran","job title":"Nurse","car model year":1989,"car make":"Chevrolet","car model":"Corvette","price":"70,139 Hryvnia"},
# {"currency":"Pound","currency code":"SYP","gender":"Female","race":"Kiowa","job title":"Statistician III","car model year":2001,"car make":"Hyundai","car model":"Tiburon","price":"887,464 Pound"},
# {"currency":"Krone","currency code":"NOK","gender":"Male","race":"Latin American Indian","job title":"Civil Engineer","car model year":2002,"car make":"Kia","car model":"Sportage","price":"5,695 Krone"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Iroquois","job title":"Database Administrator III","car model year":2012,"car make":"MINI","car model":"Countryman","price":"2,378 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"American Indian","job title":"Recruiter","car model year":2001,"car make":"Dodge","car model":"Ram 2500","price":"84,459 Rupiah"},
# {"currency":"Rupee","currency code":"PKR","gender":"Male","race":"Asian","job title":"Nuclear Power Engineer","car model year":1973,"car make":"Chevrolet","car model":"Camaro","price":"523,712 Rupee"},
# {"currency":"Zloty","currency code":"PLN","gender":"Male","race":"Blackfeet","job title":"Geological Engineer","car model year":2012,"car make":"BMW","car model":"1 Series","price":"25,738 Zloty"},
# {"currency":"Tugrik","currency code":"MNT","gender":"Male","race":"Micronesian","job title":"Engineer I","car model year":2011,"car make":"Ford","car model":"Transit Connect","price":"247,064 Tugrik"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Menominee","job title":"Software Consultant","car model year":1994,"car make":"Lincoln","car model":"Mark VIII","price":"530,668 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Ute","job title":"Human Resources Manager","car model year":2006,"car make":"Nissan","car model":"Armada","price":"199,495 Rupiah"},
# {"currency":"Afghani","currency code":"AFN","gender":"Male","race":"Salvadoran","job title":"Human Resources Assistant III","car model year":2000,"car make":"Mitsubishi","car model":"Montero Sport","price":"79,789 Afghani"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Chamorro","job title":"Web Developer IV","car model year":2008,"car make":"Cadillac","car model":"STS","price":"5,527 Rupiah"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Comanche","job title":"Geological Engineer","car model year":2004,"car make":"Cadillac","car model":"SRX","price":"036,637 Yuan Renminbi"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Blackfeet","job title":"Nurse Practicioner","car model year":1984,"car make":"Mercury","car model":"Grand Marquis","price":"1,889 Euro"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Thai","job title":"Legal Assistant","car model year":2004,"car make":"Volkswagen","car model":"Golf","price":"3,498 Rupiah"},
# {"currency":"Franc","currency code":"XAF","gender":"Female","race":"Lumbee","job title":"Account Coordinator","car model year":1992,"car make":"Chevrolet","car model":"1500","price":"06,725 Franc"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Korean","job title":"Quality Engineer","car model year":2012,"car make":"Acura","car model":"ZDX","price":"8,994 Euro"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Osage","job title":"Project Manager","car model year":1987,"car make":"Mazda","car model":"626","price":"84,402 Yuan Renminbi"},
# {"currency":"Krona","currency code":"SEK","gender":"Female","race":"Tongan","job title":"Accounting Assistant II","car model year":1997,"car make":"Toyota","car model":"RAV4","price":"8,191 Krona"},
# {"currency":"Hryvnia","currency code":"UAH","gender":"Female","race":"Osage","job title":"Health Coach IV","car model year":1992,"car make":"Acura","car model":"NSX","price":"4,216 Hryvnia"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Seminole","job title":"Editor","car model year":2004,"car make":"Honda","car model":"Pilot","price":"07,391 Euro"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Alaskan Athabascan","job title":"Chemical Engineer","car model year":1988,"car make":"Mitsubishi","car model":"Galant","price":"82,575 Yuan Renminbi"},
# {"currency":"Lempira","currency code":"HNL","gender":"Female","race":"Cherokee","job title":"Structural Analysis Engineer","car model year":1999,"car make":"Buick","car model":"Riviera","price":"707,206 Lempira"},
# {"currency":"Dinar","currency code":"RSD","gender":"Male","race":"Fijian","job title":"Legal Assistant","car model year":2001,"car make":"BMW","car model":"7 Series","price":"467,032 Dinar"},
# {"currency":"Ruble","currency code":"RUB","gender":"Female","race":"Blackfeet","job title":"Biostatistician I","car model year":2003,"car make":"Dodge","car model":"Durango","price":"826,479 Ruble"},
# {"currency":"Ruble","currency code":"RUB","gender":"Female","race":"Chickasaw","job title":"Media Manager IV","car model year":2001,"car make":"Mercedes-Benz","car model":"E-Class","price":"411,185 Ruble"},
# {"currency":"Bolivar","currency code":"VEF","gender":"Male","race":"Asian","job title":"Occupational Therapist","car model year":1989,"car make":"Buick","car model":"Estate","price":"40,488 Bolivar"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Lumbee","job title":"Software Engineer I","car model year":1993,"car make":"Chevrolet","car model":"Blazer","price":"38,230 Euro"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Comanche","job title":"Design Engineer","car model year":2001,"car make":"Audi","car model":"A4","price":"6,617 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Samoan","job title":"Programmer Analyst I","car model year":2008,"car make":"Mazda","car model":"Miata MX-5","price":"1,496 Yuan Renminbi"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Pima","job title":"Account Representative II","car model year":2000,"car make":"Mercedes-Benz","car model":"E-Class","price":"42,690 Peso"},
# {"currency":"Yen","currency code":"JPY","gender":"Male","race":"Costa Rican","job title":"Senior Financial Analyst","car model year":1990,"car make":"Mitsubishi","car model":"Pajero","price":"3,650 Yen"},
# {"currency":"Baht","currency code":"THB","gender":"Male","race":"Alaska Native","job title":"Assistant Professor","car model year":2001,"car make":"Mazda","car model":"MX-5","price":"8,035 Baht"},
# {"currency":"Peso","currency code":"PHP","gender":"Male","race":"Uruguayan","job title":"Office Assistant IV","car model year":2006,"car make":"Mazda","car model":"MPV","price":"7,806 Peso"},
# {"currency":"Real","currency code":"BRL","gender":"Male","race":"Yuman","job title":"Cost Accountant","car model year":2012,"car make":"Lincoln","car model":"MKT","price":"211,407 Real"},
# {"currency":"Peso","currency code":"CUP","gender":"Female","race":"Bolivian","job title":"Social Worker","car model year":2010,"car make":"Suzuki","car model":"Grand Vitara","price":"634,334 Peso"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Guatemalan","job title":"Internal Auditor","car model year":1999,"car make":"Dodge","car model":"Ram Van 1500","price":"4,312 Peso"},
# {"currency":"Real","currency code":"BRL","gender":"Female","race":"Korean","job title":"Human Resources Manager","car model year":2005,"car make":"Nissan","car model":"Armada","price":"60,873 Real"},
# {"currency":"Dinar","currency code":"KWD","gender":"Female","race":"Korean","job title":"Accountant I","car model year":2007,"car make":"Infiniti","car model":"G35","price":"792,964 Dinar"},
# {"currency":"Dollar","currency code":"USD","gender":"Male","race":"Panamanian","job title":"Media Manager III","car model year":2011,"car make":"GMC","car model":"Canyon","price":"51,136 Dollar"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Costa Rican","job title":"Assistant Professor","car model year":2011,"car make":"Dodge","car model":"Ram","price":"15,405 Euro"},
# {"currency":"Dinar","currency code":"TND","gender":"Male","race":"Yuman","job title":"Biostatistician IV","car model year":1996,"car make":"Ford","car model":"E-Series","price":"54,613 Dinar"},
# ...
# {"currency":"Dinar","currency code":"LYD","gender":"Male","race":"Micronesian","job title":"Engineer II","car model year":2012,"car make":"Lexus","car model":"IS","price":"105,201 Dinar"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Seminole","job title":"Cost Accountant","car model year":2010,"car make":"Dodge","car model":"Ram 2500","price":"7,573 Yuan Renminbi"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Pueblo","job title":"Compensation Analyst","car model year":2002,"car make":"Buick","car model":"Park Avenue","price":"55,315 Peso"},
# {"currency":"Real","currency code":"BRL","gender":"Female","race":"Delaware","job title":"Senior Cost Accountant","car model year":1995,"car make":"Ford","car model":"Ranger","price":"556,759 Real"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Apache","job title":"Software Test Engineer II","car model year":2002,"car make":"Ford","car model":"F150","price":"8,830 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Female","race":"Potawatomi","job title":"Assistant Manager","car model year":2003,"car make":"Hummer","car model":"H2","price":"1,142 Rupiah"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"South American","job title":"Paralegal","car model year":1992,"car make":"Chevrolet","car model":"G-Series G30","price":"239,182 Rupiah"},
# {"currency":"Ruble","currency code":"RUB","gender":"Female","race":"Filipino","job title":"Civil Engineer","car model year":1995,"car make":"Chevrolet","car model":"Impala","price":"30,756 Ruble"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Melanesian","job title":"Financial Advisor","car model year":1989,"car make":"Volkswagen","car model":"Type 2","price":"83,896 Euro"},
# {"currency":"Taka","currency code":"BDT","gender":"Female","race":"Venezuelan","job title":"Accounting Assistant I","car model year":1984,"car make":"Lotus","car model":"Esprit Turbo","price":"30,859 Taka"},
# {"currency":"Yen","currency code":"JPY","gender":"Female","race":"Hmong","job title":"Nurse","car model year":2010,"car make":"Dodge","car model":"Challenger","price":"888,023 Yen"},
# {"currency":"Real","currency code":"BRL","gender":"Male","race":"Colville","job title":"Systems Administrator III","car model year":1993,"car make":"Mercedes-Benz","car model":"500SL","price":"132,719 Real"},
# {"currency":"Lempira","currency code":"HNL","gender":"Male","race":"Puerto Rican","job title":"Staff Scientist","car model year":1993,"car make":"Mercedes-Benz","car model":"E-Class","price":"35,805 Lempira"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Creek","job title":"Geologist I","car model year":2009,"car make":"Pontiac","car model":"Vibe","price":"45,443 Rupiah"},
# {"currency":"Marka","currency code":"BAM","gender":"Male","race":"Shoshone","job title":"Senior Editor","car model year":2008,"car make":"Mercedes-Benz","car model":"GL-Class","price":"8,490 Marka"},
# {"currency":"Ruble","currency code":"RUB","gender":"Male","race":"Blackfeet","job title":"Office Assistant II","car model year":2004,"car make":"Mitsubishi","car model":"Lancer Evolution","price":"0,933 Ruble"},
# {"currency":"Peso","currency code":"DOP","gender":"Male","race":"Ecuadorian","job title":"Nurse","car model year":2012,"car make":"BMW","car model":"6 Series","price":"23,563 Peso"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Ottawa","job title":"VP Sales","car model year":2008,"car make":"Audi","car model":"RS4","price":"2,438 Yuan Renminbi"},
# {"currency":"Bolivar","currency code":"VEF","gender":"Male","race":"Native Hawaiian and Other Pacific Islander (NHPI)","job title":"Research Assistant IV","car model year":1995,"car make":"Jeep","car model":"Wrangler","price":"7,532 Bolivar"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Ute","job title":"Office Assistant I","car model year":1994,"car make":"Volvo","car model":"940","price":"140,340 Euro"},
# {"currency":"Kuna","currency code":"HRK","gender":"Female","race":"Crow","job title":"Analyst Programmer","car model year":2007,"car make":"Lincoln","car model":"MKX","price":"58,278 Kuna"},
# {"currency":"Naira","currency code":"NGN","gender":"Female","race":"Seminole","job title":"Administrative Officer","car model year":1989,"car make":"Mitsubishi","car model":"Truck","price":"03,440 Naira"},
# {"currency":"Kuna","currency code":"HRK","gender":"Male","race":"Native Hawaiian and Other Pacific Islander (NHPI)","job title":"Director of Sales","car model year":2005,"car make":"Scion","car model":"xB","price":"688,654 Kuna"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Peruvian","job title":"Payment Adjustment Coordinator","car model year":1998,"car make":"Porsche","car model":"911","price":"80,850 Euro"},
# {"currency":"Real","currency code":"BRL","gender":"Male","race":"Vietnamese","job title":"Senior Developer","car model year":1991,"car make":"Volkswagen","car model":"Fox","price":"99,702 Real"},
# {"currency":"Hryvnia","currency code":"UAH","gender":"Male","race":"Spaniard","job title":"Librarian","car model year":1990,"car make":"Audi","car model":"90","price":"956,638 Hryvnia"},
# {"currency":"Rial","currency code":"IRR","gender":"Female","race":"Venezuelan","job title":"Speech Pathologist","car model year":1999,"car make":"Cadillac","car model":"Catera","price":"039,932 Rial"},
# {"currency":"Dollar","currency code":"CAD","gender":"Female","race":"Pakistani","job title":"Senior Sales Associate","car model year":2006,"car make":"Dodge","car model":"Ram 2500","price":"9,795 Dollar"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Indonesian","job title":"Budget/Accounting Analyst II","car model year":2009,"car make":"Hyundai","car model":"Santa Fe","price":"33,664 Yuan Renminbi"},
# {"currency":"Dirham","currency code":"MAD","gender":"Male","race":"Peruvian","job title":"Legal Assistant","car model year":2004,"car make":"Pontiac","car model":"Bonneville","price":"589,193 Dirham"},
# {"currency":"Yen","currency code":"JPY","gender":"Female","race":"Ottawa","job title":"Web Designer IV","car model year":2004,"car make":"Mazda","car model":"B-Series","price":"3,291 Yen"},
# {"currency":"Zloty","currency code":"PLN","gender":"Female","race":"Pueblo","job title":"Accountant II","car model year":2005,"car make":"Infiniti","car model":"Q","price":"741,965 Zloty"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Thai","job title":"Internal Auditor","car model year":2012,"car make":"Ford","car model":"F-Series Super Duty","price":"70,530 Euro"},
# {"currency":"Zloty","currency code":"PLN","gender":"Female","race":"Taiwanese","job title":"Clinical Specialist","car model year":1998,"car make":"Pontiac","car model":"Trans Sport","price":"9,131 Zloty"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Bolivian","job title":"Programmer Analyst IV","car model year":2002,"car make":"Toyota","car model":"Celica","price":"477,817 Yuan Renminbi"},
# {"currency":"Peso","currency code":"PHP","gender":"Male","race":"Navajo","job title":"Chemical Engineer","car model year":2005,"car make":"Chevrolet","car model":"Uplander","price":"650,310 Peso"},
# {"currency":"Peso","currency code":"ARS","gender":"Female","race":"Shoshone","job title":"Accountant I","car model year":2006,"car make":"Ford","car model":"Expedition","price":"11,741 Peso"},
# {"currency":"Kip","currency code":"LAK","gender":"Female","race":"Puerto Rican","job title":"Nurse Practicioner","car model year":1967,"car make":"Pontiac","car model":"Firebird","price":"692,379 Kip"},
# {"currency":"Lempira","currency code":"HNL","gender":"Male","race":"Spaniard","job title":"Web Designer III","car model year":2002,"car make":"Ford","car model":"Explorer","price":"2,797 Lempira"},
# {"currency":"Dirham","currency code":"MAD","gender":"Male","race":"Comanche","job title":"Environmental Specialist","car model year":1993,"car make":"Mitsubishi","car model":"Mighty Max","price":"35,827 Dirham"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Micronesian","job title":"Speech Pathologist","car model year":1995,"car make":"Lexus","car model":"LS","price":"3,111 Yuan Renminbi"},
# {"currency":"Ruble","currency code":"RUB","gender":"Female","race":"Puget Sound Salish","job title":"Dental Hygienist","car model year":1993,"car make":"Alfa Romeo","car model":"Spider","price":"3,176 Ruble"},
# {"currency":"Real","currency code":"BRL","gender":"Female","race":"Chippewa","job title":"Assistant Manager","car model year":2007,"car make":"Ford","car model":"Five Hundred","price":"3,300 Real"},
# {"currency":"Peso","currency code":"PHP","gender":"Male","race":"Bolivian","job title":"Senior Sales Associate","car model year":1988,"car make":"Mitsubishi","car model":"L300","price":"51,120 Peso"},
# {"currency":"Dirham","currency code":"MAD","gender":"Female","race":"Hmong","job title":"Librarian","car model year":2009,"car make":"Audi","car model":"TT","price":"4,039 Dirham"},
# {"currency":"Dollar","currency code":"CAD","gender":"Female","race":"South American","job title":"Payment Adjustment Coordinator","car model year":1993,"car make":"Mitsubishi","car model":"Mighty Max Macro","price":"05,108 Dollar"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Tlingit-Haida","job title":"Associate Professor","car model year":1986,"car make":"Audi","car model":"4000s","price":"159,382 Yuan Renminbi"},
# {"currency":"Euro","currency code":"EUR","gender":"Female","race":"Yuman","job title":"Software Engineer IV","car model year":2003,"car make":"Dodge","car model":"Stratus","price":"27,308 Euro"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Indonesian","job title":"Software Test Engineer I","car model year":1994,"car make":"Volkswagen","car model":"Jetta III","price":"46,532 Rupiah"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Panamanian","job title":"Statistician I","car model year":1993,"car make":"Mazda","car model":"RX-7","price":"39,147 Rupiah"},
# {"currency":"Dollar","currency code":"USD","gender":"Female","race":"Asian Indian","job title":"Help Desk Operator","car model year":2011,"car make":"Subaru","car model":"Outback","price":"608,184 Dollar"},
# {"currency":"Shilling","currency code":"TZS","gender":"Female","race":"Salvadoran","job title":"Assistant Professor","car model year":1990,"car make":"Lamborghini","car model":"Diablo","price":"2,103 Shilling"},
# {"currency":"Dong","currency code":"VND","gender":"Male","race":"Micronesian","job title":"Programmer Analyst III","car model year":1984,"car make":"Mitsubishi","car model":"Starion","price":"1,262 Dong"},
# {"currency":"Real","currency code":"BRL","gender":"Female","race":"Cuban","job title":"Structural Analysis Engineer","car model year":1984,"car make":"Volkswagen","car model":"Scirocco","price":"128,916 Real"},
# {"currency":"Dollar","currency code":"USD","gender":"Male","race":"Malaysian","job title":"Financial Advisor","car model year":1997,"car make":"Land Rover","car model":"Defender","price":"49,254 Dollar"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Puerto Rican","job title":"Chemical Engineer","car model year":2006,"car make":"BMW","car model":"3 Series","price":"498,176 Yuan Renminbi"},
# {"currency":"Shekel","currency code":"ILS","gender":"Male","race":"Sioux","job title":"Civil Engineer","car model year":1998,"car make":"Lincoln","car model":"Mark VIII","price":"744,485 Shekel"},
# {"currency":"Peso","currency code":"CLP","gender":"Female","race":"Chilean","job title":"Environmental Specialist","car model year":2004,"car make":"Kia","car model":"Amanti","price":"275,113 Peso"},
# {"currency":"Dollar","currency code":"USD","gender":"Male","race":"Shoshone","job title":"Media Manager III","car model year":2007,"car make":"GMC","car model":"Savana 1500","price":"09,711 Dollar"},
# {"currency":"Lev","currency code":"BGN","gender":"Male","race":"Alaskan Athabascan","job title":"Analog Circuit Design manager","car model year":1998,"car make":"Isuzu","car model":"Trooper","price":"377,635 Lev"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Cree","job title":"Mechanical Systems Engineer","car model year":2007,"car make":"Volkswagen","car model":"Rabbit","price":"27,143 Peso"},
# {"currency":"Dinar","currency code":"RSD","gender":"Female","race":"Kiowa","job title":"Technical Writer","car model year":2009,"car make":"Hyundai","car model":"Santa Fe","price":"07,135 Dinar"},
# {"currency":"Peso","currency code":"CUP","gender":"Female","race":"Native Hawaiian and Other Pacific Islander (NHPI)","job title":"Help Desk Operator","car model year":2011,"car make":"MINI","car model":"Cooper","price":"92,923 Peso"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Osage","job title":"GIS Technical Architect","car model year":1998,"car make":"Cadillac","car model":"Eldorado","price":"541,788 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Ecuadorian","job title":"Graphic Designer","car model year":2008,"car make":"Mercedes-Benz","car model":"SLK-Class","price":"0,503 Yuan Renminbi"},
# {"currency":"Rupiah","currency code":"IDR","gender":"Male","race":"Micronesian","job title":"Developer II","car model year":1993,"car make":"Chevrolet","car model":"G-Series G30","price":"79,223 Rupiah"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Malaysian","job title":"Engineer III","car model year":1994,"car make":"Mazda","car model":"MX-6","price":"94,872 Yuan Renminbi"},
# {"currency":"Peso","currency code":"PHP","gender":"Female","race":"Venezuelan","job title":"Research Assistant I","car model year":2005,"car make":"Porsche","car model":"Carrera GT","price":"26,811 Peso"},
# {"currency":"Koruna","currency code":"CZK","gender":"Female","race":"Cree","job title":"Administrative Officer","car model year":2005,"car make":"Nissan","car model":"Titan","price":"9,521 Koruna"},
# {"currency":"Cordoba","currency code":"NIO","gender":"Female","race":"Potawatomi","job title":"Analyst Programmer","car model year":2007,"car make":"Scion","car model":"tC","price":"39,971 Cordoba"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Female","race":"Lumbee","job title":"Accounting Assistant II","car model year":1994,"car make":"Chevrolet","car model":"1500","price":"7,169 Yuan Renminbi"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Uruguayan","job title":"Community Outreach Specialist","car model year":1997,"car make":"Subaru","car model":"SVX","price":"35,329 Yuan Renminbi"},
# {"currency":"Balboa","currency code":"PAB","gender":"Female","race":"Argentinian","job title":"Occupational Therapist","car model year":1996,"car make":"Mitsubishi","car model":"Montero","price":"95,534 Balboa"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Crow","job title":"Pharmacist","car model year":2002,"car make":"Dodge","car model":"Ram Van 1500","price":"09,786 Euro"},
# {"currency":"Kuna","currency code":"HRK","gender":"Male","race":"American Indian","job title":"Payment Adjustment Coordinator","car model year":2003,"car make":"Toyota","car model":"Matrix","price":"2,381 Kuna"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Paraguayan","job title":"Analyst Programmer","car model year":1990,"car make":"Buick","car model":"Skylark","price":"8,018 Euro"},
# {"currency":"Euro","currency code":"EUR","gender":"Male","race":"Pueblo","job title":"Geologist III","car model year":1969,"car make":"Mercury","car model":"Cougar","price":"76,353 Euro"},
# {"currency":"Yuan Renminbi","currency code":"CNY","gender":"Male","race":"Filipino","job title":"Assistant Media Planner","car model year":2010,"car make":"Kia","car model":"Optima","price":"2,185 Yuan Renminbi"}]

# %% [markdown]
# ## Step 6: Importing the data to Python for analysis (Data Understanding - Iterative)
#
# There are two core libraries used for data analysis in Python:
# - the pandas library essential to data analysis & used for advanced data manipulation, stores data in dataframe
# - the NumPy library for scientific computing, mathematical operations stores data in N dimensional arrays(1D,2D,3D)
#
# We will demonstrate both, first importing our data into Python for data analysis using these libraries via the code below:

# %%
#loading libraries in memory for us to work with our data
import pandas as pd
import numpy as np

# %%
#storing our JSON file to a dataframe & load first sheet of JSON file into pandas dataframe
jsonfile = '/users/brandyguillory/Jupyter Files/pricedata.json'
df = pd.read_json(jsonfile, orient='columns')
# There was 1000 rows in our JSON file of data, the below command will print our dataframe contents
df.head(1000)
# Out:
#           car make          car model  car model year       currency  \
# 0            Mazda               RX-7            1984  Yuan Renminbi
# 1            Buick        Park Avenue            1997           Euro
# 2       Mitsubishi             Pajero            1995       Shilling
# 3        Chevrolet            Tracker            2000         Dollar
# 4             Ford             Taurus            1998           Euro
# 5            Dodge            Stratus            1996          Naira
# 6            Acura                 RL            2001           Real
# 7       Volkswagen             Passat            2012           Real
# 8            Lexus                 ES            2006           Euro
# 9         Chrysler     Town & Country            2006          Ruble
# 10            Saab               9000            1989        Bolivar
# 11       Chevrolet             Camaro            2000          Zloty
# 12            Ford           F-Series            1992         Tugrik
# 13   Mercedes-Benz           CL-Class            2007         Rupiah
# 14           Honda               CR-Z            2011           Peso
# 15       Chevrolet          Avalanche            2002           Real
# 16       Chevrolet              Astro            1995  Yuan Renminbi
# 17          Suzuki     Daewoo Lacetti            2007  Yuan Renminbi
# 18     Lamborghini             Diablo            1993  Yuan Renminbi
# 19           Acura                 RL            2006  Yuan Renminbi
# 20           Mazda           B-Series            2008         Rupiah
# 21         Mercury           Villager            1995          Ruble
# 22            Saab               9000            1997          Dinar
# 23         Maybach                 57            2012         Dollar
# 24       Chevrolet       Express 1500            2002           Kyat
# 25           Lexus                 LS            1996        Afghani
# 26     Lamborghini           Gallardo            2004         Rupiah
# 27   Mercedes-Benz           SL-Class            2012           Peso
# 28             Kia           Sportage            2000          Rupee
# 29          Toyota  Truck Xtracab SR5            1989  Yuan Renminbi
# ..             ...                ...             ...            ...
# 970     Volkswagen          Jetta III            1994         Rupiah
# 971          Mazda               RX-7            1993         Rupiah
# 972         Subaru            Outback            2011         Dollar
# 973    Lamborghini             Diablo            1990       Shilling
# 974     Mitsubishi            Starion            1984           Dong
# 975     Volkswagen           Scirocco            1984           Real
# 976     Land Rover           Defender            1997         Dollar
# 977            BMW           3 Series            2006  Yuan Renminbi
# 978        Lincoln          Mark VIII            1998         Shekel
# 979            Kia             Amanti            2004           Peso
# 980            GMC        Savana 1500            2007         Dollar
# 981          Isuzu            Trooper            1998            Lev
# 982     Volkswagen             Rabbit            2007           Peso
# 983        Hyundai           Santa Fe            2009          Dinar
# 984           MINI             Cooper            2011           Peso
# 985       Cadillac           Eldorado            1998  Yuan Renminbi
# 986  Mercedes-Benz          SLK-Class            2008  Yuan Renminbi
# 987      Chevrolet       G-Series G30            1993         Rupiah
# 988          Mazda               MX-6            1994  Yuan Renminbi
# 989        Porsche         Carrera GT            2005           Peso
# 990         Nissan              Titan            2005         Koruna
# 991          Scion                 tC            2007        Cordoba
# 992      Chevrolet               1500            1994  Yuan Renminbi
# 993         Subaru                SVX            1997  Yuan Renminbi
# 994     Mitsubishi            Montero            1996         Balboa
# 995          Dodge       Ram Van 1500            2002           Euro
# 996         Toyota             Matrix            2003           Kuna
# 997          Buick            Skylark            1990           Euro
# 998        Mercury             Cougar            1969           Euro
# 999            Kia             Optima            2010  Yuan Renminbi
#
#     currency code  gender                       job title  \
# 0             CNY    Male             Marketing Assistant
# 1             EUR    Male           Chief Design Engineer
# 2             UGX  Female          Senior Cost Accountant
# 3             CAD  Female               Assistant Manager
# 4             EUR  Female        Senior Financial Analyst
# 5             NGN  Female                Registered Nurse
# 6             BRL    Male                Product Engineer
# 7             BRL  Female          Programmer Analyst III
# 8             EUR    Male               Financial Advisor
# 9             RUB    Male                  Accountant III
# 10            VEF    Male           Research Assistant IV
# 11            PLN    Male                 Legal Assistant
# 12            MNT  Female      Database Administrator III
# 13            IDR  Female                Senior Developer
# 14            ARS  Female         Human Resources Manager
# 15            BRL    Male   Human Resources Assistant III
# 16            CNY    Male                       Professor
# 17            CNY    Male             Geological Engineer
# 18            CNY  Female               Chemical Engineer
# 19            CNY    Male             Clinical Specialist
# 20            IDR  Female                Product Engineer
# 21            RUB    Male               Financial Advisor
# 22            TND    Male                Product Engineer
# 23            CAD  Female              Analyst Programmer
# 24            MMK    Male         Senior Quality Engineer
# 25            AFN  Female               Financial Analyst
# 26            IDR  Female          Occupational Therapist
# 27            COP    Male                   Accountant II
# 28            PKR    Male         Human Resources Manager
# 29            CNY  Female              Nurse Practicioner
# ..            ...     ...                             ...
# 970           IDR    Male        Software Test Engineer I
# 971           IDR    Male                  Statistician I
# 972           USD  Female              Help Desk Operator
# 973           TZS  Female             Assistant Professor
# 974           VND    Male          Programmer Analyst III
# 975           BRL  Female    Structural Analysis Engineer
# 976           USD    Male               Financial Advisor
# 977           CNY  Female               Chemical Engineer
# 978           ILS    Male                  Civil Engineer
# 979           CLP  Female        Environmental Specialist
# 980           USD    Male               Media Manager III
# 981           BGN    Male   Analog Circuit Design manager
# 982           PHP  Female     Mechanical Systems Engineer
# 983           RSD  Female                Technical Writer
# 984           CUP  Female              Help Desk Operator
# 985           CNY  Female         GIS Technical Architect
# 986           CNY  Female                Graphic Designer
# 987           IDR    Male                    Developer II
# 988           CNY  Female                    Engineer III
# 989           PHP  Female            Research Assistant I
# 990           CZK  Female          Administrative Officer
# 991           NIO  Female              Analyst Programmer
# 992           CNY  Female         Accounting Assistant II
# 993           CNY    Male   Community Outreach Specialist
# 994           PAB  Female          Occupational Therapist
# 995           EUR    Male                      Pharmacist
# 996           HRK    Male  Payment Adjustment Coordinator
# 997           EUR    Male              Analyst Programmer
# 998           EUR    Male                   Geologist III
# 999           CNY    Male         Assistant Media Planner
#
#                      price                                               race
# 0      4,323 Yuan Renminbi                                             Samoan
# 1              95,173 Euro                                              Creek
# 2         458,483 Shilling                                        Costa Rican
# 3            08,262 Dollar                                           Seminole
# 4               6,854 Euro                                            Laotian
# 5             20,459 Naira                                              Hmong
# 6               6,635 Real                                             Lumbee
# 7              59,099 Real                                         Melanesian
# 8               4,144 Euro                                             Samoan
# 9            440,768 Ruble                                            Mexican
# 10          00,968 Bolivar                                   Central American
# 11             6,076 Zloty                                              Cuban
# 12            0,370 Tugrik                          Black or African American
# 13            5,593 Rupiah                                         Sri Lankan
# 14            920,722 Peso                                               Thai
# 15             78,780 Real                                           Comanche
# 16     0,497 Yuan Renminbi                                           Cheyenne
# 17     4,981 Yuan Renminbi                                             Lumbee
# 18   681,627 Yuan Renminbi                                             Lumbee
# 19     7,905 Yuan Renminbi                                         Polynesian
# 20          241,265 Rupiah                                               Thai
# 21             2,660 Ruble                                           Bolivian
# 22             3,227 Dinar                                         Panamanian
# 23           16,491 Dollar                                             Navajo
# 24              2,094 Kyat                                         Salvadoran
# 25          85,769 Afghani                                     South American
# 26          909,737 Rupiah                                              Asian
# 27             15,448 Peso                                         Panamanian
# 28           749,567 Rupee                                           Comanche
# 29   866,139 Yuan Renminbi                                           Filipino
# ..                     ...                                                ...
# 970          46,532 Rupiah                                         Indonesian
# 971          39,147 Rupiah                                         Panamanian
# 972         608,184 Dollar                                       Asian Indian
# 973         2,103 Shilling                                         Salvadoran
# 974             1,262 Dong                                        Micronesian
# 975           128,916 Real                                              Cuban
# 976          49,254 Dollar                                          Malaysian
# 977  498,176 Yuan Renminbi                                       Puerto Rican
# 978         744,485 Shekel                                              Sioux
# 979           275,113 Peso                                            Chilean
# 980          09,711 Dollar                                           Shoshone
# 981            377,635 Lev                                 Alaskan Athabascan
# 982            27,143 Peso                                               Cree
# 983           07,135 Dinar                                              Kiowa
# 984            92,923 Peso  Native Hawaiian and Other Pacific Islander (NHPI)
# 985  541,788 Yuan Renminbi                                              Osage
# 986    0,503 Yuan Renminbi                                         Ecuadorian
# 987          79,223 Rupiah                                        Micronesian
# 988   94,872 Yuan Renminbi                                          Malaysian
# 989            26,811 Peso                                         Venezuelan
# 990           9,521 Koruna                                               Cree
# 991         39,971 Cordoba                                         Potawatomi
# 992    7,169 Yuan Renminbi                                             Lumbee
# 993   35,329 Yuan Renminbi                                          Uruguayan
# 994          95,534 Balboa                                        Argentinian
# 995            09,786 Euro                                               Crow
# 996             2,381 Kuna                                    American Indian
# 997             8,018 Euro                                         Paraguayan
# 998            76,353 Euro                                             Pueblo
# 999    2,185 Yuan Renminbi                                           Filipino
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## __Step 7: Understand variables/data spreads & convert to dataset (Data Understanding & Data Preprocessing - Iterative)
#
# **Data Understanding:**
#
# Look at Summary statistics and visualizations
#    - Percentiles can help identify the range for most of the data
#    - Averages and medians can describe central tendency
#    - Correlations can indicate strong relationships
#
# Visualize the data
#    - Box plots can identify outliers
#    - Density plots and histograms show the spread of data
#    - Scatter plots can describe bivariate relationships
#
# **Preprocessing is taking the raw data as we have done above(JSON) and convert to a client data set in four steps:**
#
# - Data Cleaning: handling and correcting the following
#         - missing data
#         - noisy data(meaningless/corrupted)
#         - detection and removal of outliers
#         - minimizing duplication and computed biases within the data
#
# - Data Integration:(Data aggregation part of process) take vast quantities of data from disparate sources combined to                    form consistent data. This consistent data after performing data cleaning is used for analysis
#
# - Data Transformation: convert the raw data into a specified format according to the need of the model:
#        - Normalization - In this method, numerical data is converted into the specified range, i.e., between 0 and one          so that scaling of data can be performed.
#        - Aggregation - The concept can be derived from the word itself, this method is used to combine the features            into one. For example, combining two categories can be used to form a new group.
#        - Generalization - In this case, lower level attributes are converted to a higher standard.
#
# - Data Reduction: redundancy within the data is removed and efficiently organize the data
#
#
# We will now store our JSON data file into a pandas dataframe using the executable code below and we will perform the data understanding step of data cleaning:

# %% [markdown]
# We will now store our pandas dataframe into a numPY array using the executable code below:

# %%
numarray = df.values
print(numarray)
# Out:
# [['Mazda' 'RX-7' 1984 ... 'Marketing Assistant' '4,323 Yuan Renminbi'
#   'Samoan']
#  ['Buick' 'Park Avenue' 1997 ... 'Chief Design Engineer' '95,173 Euro'
#   'Creek']
#  ['Mitsubishi' 'Pajero' 1995 ... 'Senior Cost Accountant'
#   '458,483 Shilling' 'Costa Rican']
#  ...
#  ['Buick' 'Skylark' 1990 ... 'Analyst Programmer' '8,018 Euro'
#   'Paraguayan']
#  ['Mercury' 'Cougar' 1969 ... 'Geologist III' '76,353 Euro' 'Pueblo']
#  ['Kia' 'Optima' 2010 ... 'Assistant Media Planner' '2,185 Yuan Renminbi'
#   'Filipino']]

# %% [markdown]
# ## __Step 8: Modeling the Data__
#
# Goal?
#
# Data Wrangling is performed during the iterative analysis and model building(enrich, cleanse, structure, publish documented process)
# - I am using Python3 for data wrangling(pandas, numpy, scipy)

# %% [markdown]
# ## __Step 8: Validating the Model(Evaluation)__
#
# Goal - accuracy?
#
# Training models(scikit-learn)
# Visualizations (bokeh,seaborn, matplotlib)

# %% [markdown]
# ## __Step 9: Deploying the Model__

# %% [markdown]
# ## __Step 10: Updating the Model & Keep it Relevant(Feedback)__
#
# Data
# Improvement on model(add more enrichments etc)
